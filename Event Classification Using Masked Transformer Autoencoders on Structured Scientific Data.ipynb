# %% [markdown]
# ## Import neccesary libraries

# %%
import pandas as pd

# %% [markdown]
# ## Load HAR (Human Activity Recongition Dataset)

# %%
train_x_path = r"C:\Users\UltraBook 3.1\Desktop\data_analysis projects\Masked Autoencoders\UCI HAR Dataset\train\X_train.txt"
train_y_path = r"C:\Users\UltraBook 3.1\Desktop\data_analysis projects\Masked Autoencoders\UCI HAR Dataset\train\y_train.txt"

X_train = pd.read_csv(
    train_x_path,
    sep=r"\s+",
    header=None
)

y_train = pd.read_csv(
   train_y_path,
    header=None
).astype(int)

# %% [markdown]
# ## Data Summary (Understanding the Dataset)
# The X train dataset consists of 7352 rows which represent events and 561 coumns acting as features. Convert the y_train numbers from 1-6 to 0-5 to ease train of thought.

# %% [markdown]
# The table has 561 columns or features. Each column mapped to a value and the details of the features located in a different file features.txt. However these columns do not show any descriptive information directly from the table.
#
# The features selected for this database come from the accelerometer and gyroscope 3-axial raw signals tAcc-XYZ and tGyro-XYZ. These time domain signals (prefix 't' to denote time) were captured at a constant rate of 50 Hz. Then they were filtered using a median filter and a 3rd order low pass Butterworth filter with a corner frequency of 20 Hz to remove noise. Similarly, the acceleration signal was then separated into body and gravity acceleration signals (tBodyAcc-XYZ and tGravityAcc-XYZ) using another low pass Butterworth filter with a corner frequency of 0.3 Hz.
#
# Subsequently, the body linear acceleration and angular velocity were derived in time to obtain Jerk signals (tBodyAccJerk-XYZ and tBodyGyroJerk-XYZ). Also the magnitude of these three-dimensional signals were calculated using the Euclidean norm (tBodyAccMag, tGravityAccMag, tBodyAccJerkMag, tBodyGyroMag, tBodyGyroJerkMag).
# Finally a Fast Fourier Transform (FFT) was applied to some of these signals producing fBodyAcc-XYZ, fBodyAccJerk-XYZ, fBodyGyro-XYZ, fBodyAccJerkMag, fBodyGyroMag, fBodyGyroJerkMag. (Note the 'f' to indicate frequency domain signals).
#
# These signals were used to estimate variables of the feature vector for each pattern:
# '-XYZ' is used to denote 3-axial signals in the X, Y and Z directions.
#
# tBodyAcc-XYZ
# tGravityAcc-XYZ
# tBodyAccJerk-XYZ
# tBodyGyro-XYZ
# tBodyGyroJerk-XYZ
# tBodyAccMag
# tGravityAccMag
# tBodyAccJerkMag
# tBodyGyroMag
# tBodyGyroJerkMag
# fBodyAcc-XYZ
# fBodyAccJerk-XYZ
# fBodyGyro-XYZ
# fBodyAccMag
# fBodyAccJerkMag
# fBodyGyroMag
# fBodyGyroJerkMag

# %%
X_train
# Out:
#            0         1         2         3         4         5         6    \
# 0     0.288585 -0.020294 -0.132905 -0.995279 -0.983111 -0.913526 -0.995112
# 1     0.278419 -0.016411 -0.123520 -0.998245 -0.975300 -0.960322 -0.998807
# 2     0.279653 -0.019467 -0.113462 -0.995380 -0.967187 -0.978944 -0.996520
# 3     0.279174 -0.026201 -0.123283 -0.996091 -0.983403 -0.990675 -0.997099
# 4     0.276629 -0.016570 -0.115362 -0.998139 -0.980817 -0.990482 -0.998321
# ...        ...       ...       ...       ...       ...       ...       ...
# 7347  0.299665 -0.057193 -0.181233 -0.195387  0.039905  0.077078 -0.282301
# 7348  0.273853 -0.007749 -0.147468 -0.235309  0.004816  0.059280 -0.322552
# 7349  0.273387 -0.017011 -0.045022 -0.218218 -0.103822  0.274533 -0.304515
# 7350  0.289654 -0.018843 -0.158281 -0.219139 -0.111412  0.268893 -0.310487
# 7351  0.351503 -0.012423 -0.203867 -0.269270 -0.087212  0.177404 -0.377404
#
# ...

# %% [markdown]
# ## Data preprocessing

# %%
y_train[0].unique()
# Out:
# array([5, 4, 6, 1, 3, 2])

# %%
# converting to 0-5
y_train = y_train - 1

# %%
y_train[0].unique()
# Out:
# array([4, 3, 5, 0, 2, 1])

# %%
# no missing values
X_train.isna().sum()
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 556    0
# 557    0
# 558    0
# 559    0
# 560    0
# Length: 561, dtype: int64

# %%
# all features are float dtype
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7352 entries, 0 to 7351
# Columns: 561 entries, 0 to 560
# dtypes: float64(561)
# memory usage: 31.5 MB

# %%
X_train.describe()
# Out:
#                0            1            2            3            4    \
# count  7352.000000  7352.000000  7352.000000  7352.000000  7352.000000
# mean      0.274488    -0.017695    -0.109141    -0.605438    -0.510938
# std       0.070261     0.040811     0.056635     0.448734     0.502645
# min      -1.000000    -1.000000    -1.000000    -1.000000    -0.999873
# 25%       0.262975    -0.024863    -0.120993    -0.992754    -0.978129
# 50%       0.277193    -0.017219    -0.108676    -0.946196    -0.851897
# 75%       0.288461    -0.010783    -0.097794    -0.242813    -0.034231
# max       1.000000     1.000000     1.000000     1.000000     0.916238
#
#                5            6            7            8            9    ...  \
# count  7352.000000  7352.000000  7352.000000  7352.000000  7352.000000  ...
# mean     -0.604754    -0.630512    -0.526907    -0.606150    -0.468604  ...
# std       0.418687     0.424073     0.485942     0.414122     0.544547  ...
# ...

# %% [markdown]
# ## Masked Function

# %%
import torch

def random_masking(x, mask_ratio=0.6):
    """
    x: (B, T, D)
    Returns:
        x_masked: masked input
        mask: 1 for masked positions, 0 otherwise
    """
    B, T, D = x.shape
    num_mask = int(T * mask_ratio)

    noise = torch.rand(B, T, device=x.device)
    ids_shuffle = torch.argsort(noise, dim=1)
    ids_restore = torch.argsort(ids_shuffle, dim=1)

    mask = torch.ones(B, T, device=x.device)
    mask[:, :T - num_mask] = 0
    mask = torch.gather(mask, dim=1, index=ids_restore)

    x_masked = x.clone()
    x_masked[mask.bool()] = 0.0

    return x_masked, mask

# %% [markdown]
# ## Transformer Encoder

# %%
import torch.nn as nn

class EventEncoder(nn.Module):
    def __init__(self, input_dim, embed_dim=128, num_layers=4, num_heads=4):
        super().__init__()

        self.embedding = nn.Linear(input_dim, embed_dim)

        encoder_layer = nn.TransformerEncoderLayer(
            d_model=embed_dim,
            nhead=num_heads,
            batch_first=True
        )
        self.encoder = nn.TransformerEncoder(
            encoder_layer, num_layers=num_layers
        )

    def forward(self, x):
        x = self.embedding(x)
        return self.encoder(x)

# %% [markdown]
# ## Transformer Decoder

# %%
class EventDecoder(nn.Module):
    def __init__(self, embed_dim=128, output_dim=10, num_layers=2, num_heads=4):
        super().__init__()

        decoder_layer = nn.TransformerEncoderLayer(
            d_model=embed_dim,
            nhead=num_heads,
            batch_first=True
        )
        self.decoder = nn.TransformerEncoder(
            decoder_layer, num_layers=num_layers
        )

        self.output_layer = nn.Linear(embed_dim, output_dim)

    def forward(self, x):
        x = self.decoder(x)
        return self.output_layer(x)

# %% [markdown]
# ## Masked Autoencoder (Full Model)

# %%
class MaskedAutoencoder(nn.Module):
    def __init__(self, input_dim):
        super().__init__()

        self.encoder = EventEncoder(input_dim)
        self.decoder = EventDecoder(output_dim=input_dim)

    def forward(self, x, mask_ratio=0.6):
        x_masked, mask = random_masking(x, mask_ratio)

        z = self.encoder(x_masked)
        recon = self.decoder(z)

        return recon, mask

# %%
## conver the data to tensors 
import torch

X_train_tensor = torch.tensor(X_train.values, dtype=torch.float32)

X_train_tensor = X_train_tensor.unsqueeze(-1) # add a dummy feature

X_train_tensor = X_train_tensor.to(device)

from torch.utils.data import DataLoader, TensorDataset

dataset = TensorDataset(X_train_tensor)
loader = DataLoader(
    dataset,
    batch_size=64,   # start small
    shuffle=True
)

# %% [markdown]
# ## Loss function (masked-only loss) & Training loop

# %%
def masked_mse_loss(pred, target, mask):
    mask = mask.unsqueeze(-1)  # (B, T, 1)
    loss = ((pred - target) ** 2) * mask
    return loss.sum() / mask.sum()


device = "cuda" if torch.cuda.is_available() else "cpu"

model = MaskedAutoencoder(input_dim=1).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
num_epochs = 14


for epoch in range(num_epochs):
    model.train()
    epoch_loss = 0.0

    for (x,) in loader:          # mini-batches
        x = x.to(device)

        recon, mask = model(x, mask_ratio=0.7)
        loss = masked_mse_loss(recon, x, mask)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        epoch_loss += loss.item()

    print(f"Epoch {epoch+1}: loss = {epoch_loss / len(loader):.4f}")
# Out:
# Epoch 1: loss = 0.3125
# Epoch 2: loss = 0.2630
# Epoch 3: loss = 0.2615
# Epoch 4: loss = 0.2609
# Epoch 5: loss = 0.2604
# Epoch 6: loss = 0.2602
# Epoch 7: loss = 0.2601
# Epoch 8: loss = 0.2599
# Epoch 9: loss = 0.2598
# Epoch 10: loss = 0.2598
# Epoch 11: loss = 0.2598
# Epoch 12: loss = 0.2596
# Epoch 13: loss = 0.2592
# Epoch 14: loss = 0.2594
